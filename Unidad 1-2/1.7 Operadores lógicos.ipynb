# %% [markdown]
# # 1.7 Operadores lógicos
#
# Los operadores lógicos siguen las reglas de la lógica proposicional
#
# ## A) AND

# %%
True and False
# Out:
# False

# %%
True and True

# %%
False and False

# %% [markdown]
# ## B) OR

# %%
True or False

# %%
True or True

# %%
False or False

# %% [markdown]
# ## C) NOT ****

# %%
not True

# %%
not False

# %% [markdown]
# ## _Operadores de comparación_
#
# == ; != ; < ; > ; >= ; >=

# %% [markdown]
# ### Para probar igualdad usamos operador ==

# %%
print("¿Se cumple que 2 == 2?\n", 2 == 2)
# Out:
# ¿Se cumple que 2 == 2?
#  True

# %% [markdown]
# ### Para probar desigualdad se usa el operador !=

# %%
print("¿Se cumple que 2 != 2\n", 2 != 2)
# Out:
# ¿Se cumple que 2 != 2
#  False

# %% [markdown]
# ### Para comparar magnitudes usamos <, >, >=, <=

# %%
print("¿Se cumple que 2 > 3\n", 2>3)

print("¿Se cumple que 2 < 3\n", 2<3)

print("¿Se cumple que 2 <= 3\n", 2<=3)

print("¿Se cumple que 2 >= 3\n", 2>=3)
# Out:
# ¿Se cumple que 2 > 3
#  False
# ¿Se cumple que 2 < 3
#  True
# ¿Se cumple que 2 <= 3
#  True
# ¿Se cumple que 2 >= 3
#  False

# %% [markdown]
# #### Los operadores básicos de comparación (<, <=, >, >=, ==, !=) también aplican a las cadenas de caracteres. Para compararlas siguen el estándard ASCII.
#
# ![image.png](attachment:image.png)

# %%
print("c" > "d", "\n", 'c' > 'b' )
# Out:
# False
#  True

# %%
print("Casa">"perro") #Si empezamos a contar desde la A; la C tiene un valor de 3 mientras la P tiene el valor de 16
# Out:
# False

# %%
print("casa">"cabra")
# Out:
# True

# %%
print("#">"!")
# Out:
# True
